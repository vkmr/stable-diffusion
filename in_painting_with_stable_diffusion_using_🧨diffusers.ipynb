# %% [markdown]
# # In-painting pipeline for Stable Diffusion using 🧨 Diffusers
#
# This notebook shows how to do text-guided in-painting with Stable Diffusion model using  🤗 Hugging Face [🧨 Diffusers library](https://github.com/huggingface/diffusers).
#
# For a general introduction to the Stable Diffusion model please refer to this [colab](https://colab.research.google.com/github/huggingface/notebooks/blob/main/diffusers/stable_diffusion.ipynb).

# %%
# !pip install -qq -U diffusers==0.6.0 transformers ftfy gradio
# !pip install git+https://github.com/huggingface/diffusers.git
# Out:
# Collecting git+https://github.com/huggingface/diffusers.git
#   Cloning https://github.com/huggingface/diffusers.git to /tmp/pip-req-build-x3gdx1fz
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git /tmp/pip-req-build-x3gdx1fz
#   Resolved https://github.com/huggingface/diffusers.git to commit 182eb959e5efc8c77fa31394ca55376331c0ed25
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: huggingface-hub>=0.10.0 in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from diffusers==0.8.0.dev0) (0.11.0)
# Requirement already satisfied: filelock in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from diffusers==0.8.0.dev0) (3.8.0)
# Requirement already satisfied: Pillow in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from diffusers==0.8.0.dev0) (9.3.0)
# Requirement already satisfied: numpy in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from diffusers==0.8.0.dev0) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from diffusers==0.8.0.dev0) (2022.10.31)
# Requirement already satisfied: importlib-metadata in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from diffusers==0.8.0.dev0) (5.0.0)
# Requirement already satisfied: requests in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from diffusers==0.8.0.dev0) (2.28.1)
# Requirement already satisfied: packaging>=20.9 in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from huggingface-hub>=0.10.0->diffusers==0.8.0.dev0) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from huggingface-hub>=0.10.0->diffusers==0.8.0.dev0) (4.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from huggingface-hub>=0.10.0->diffusers==0.8.0.dev0) (6.0)
# Requirement already satisfied: tqdm in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from huggingface-hub>=0.10.0->diffusers==0.8.0.dev0) (4.64.1)
# Requirement already satisfied: zipp>=0.5 in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from importlib-metadata->diffusers==0.8.0.dev0) (3.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from requests->diffusers==0.8.0.dev0) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from requests->diffusers==0.8.0.dev0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from requests->diffusers==0.8.0.dev0) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from requests->diffusers==0.8.0.dev0) (3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/movidius/anaconda3/envs/stable-diffusion-huggingface/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.10.0->diffusers==0.8.0.dev0) (3.0.9)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.8.0.dev0-py3-none-any.whl size=379903 sha256=5e09e5c97389f80292e2ff149756f99d5ad3cfc80bc2c43abd504965131d7d2c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xb6xwmyl/wheels/4d/b7/a8/6f9549ceec5daad78675b857ac57d697c387062506520a7b50
# Successfully built diffusers
# Installing collected packages: diffusers
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.6.0
#     Uninstalling diffusers-0.6.0:
#       Successfully uninstalled diffusers-0.6.0
# Successfully installed diffusers-0.8.0.dev0

# %% [markdown]
# We need to accept the model license before downloading or using the weights. In this post we'll use `runwayml/stable-diffusion-inpainting` model released by Runwayml so we'll need to  visit [its card](https://huggingface.co/runwayml/stable-diffusion-inpainting), read the license and tick the checkbox if you agree.
#
# You need to be a registered user in 🤗 Hugging Face Hub, and you'll also need to use an access token for the code to work. For more information on access tokens, please refer to [this section of the documentation](https://huggingface.co/docs/hub/security-tokens).

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import inspect
from typing import List, Optional, Union

import numpy as np
import torch

import PIL
import gradio as gr
from diffusers import StableDiffusionInpaintPipeline

# %%
device = "cuda"
model_path = "runwayml/stable-diffusion-inpainting"

pipe = StableDiffusionInpaintPipeline.from_pretrained(
    model_path,
    revision="fp16", 
    torch_dtype=torch.float16,
    use_auth_token=True
).to(device)
# Out:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
import requests
from io import BytesIO

def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols

    w, h = imgs[0].size
    grid = PIL.Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size
    
    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid


def download_image(url):
    response = requests.get(url)
    return PIL.Image.open(BytesIO(response.content)).convert("RGB")

img_url = "https://raw.githubusercontent.com/CompVis/latent-diffusion/main/data/inpainting_examples/overture-creations-5sI6fQgYIuo.png"
mask_url = "https://raw.githubusercontent.com/CompVis/latent-diffusion/main/data/inpainting_examples/overture-creations-5sI6fQgYIuo_mask.png"

# %%
image = download_image(img_url).resize((512, 512))
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
mask_image = download_image(mask_url).resize((512, 512))
mask_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "a mecha robot sitting on a bench"

guidance_scale=7.5
num_samples = 3
generator = torch.Generator(device="cuda").manual_seed(0) # change the seed to get different results

images = pipe(
    prompt=prompt,
    image=image,
    mask_image=mask_image,
    guidance_scale=guidance_scale,
    generator=generator,
    num_images_per_prompt=num_samples,
).images
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# insert initial image in the list so we can compare side by side
images.insert(0, image)

# %%
image_grid(images, 1, num_samples + 1)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x512>

# %% [markdown]
# ### Gradio Demo

# %%
def predict(dict, prompt):
  image =  dict['image'].convert("RGB").resize((512, 512))
  mask_image = dict['mask'].convert("RGB").resize((512, 512))
  images = pipe(prompt=prompt, image=image, mask_image=mask_image).images
  return(images[0])

# %%
gr.Interface(
    predict,
    title = 'Stable Diffusion In-Painting',
    inputs=[
        gr.Image(source = 'upload', tool = 'sketch', type = 'pil'),
        gr.Textbox(label = 'prompt')
    ],
    outputs = [
        gr.Image()
        ]
).launch(debug=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# ![inpainting_getty](./getty_inpainting.png)
